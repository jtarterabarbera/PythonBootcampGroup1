# %% [markdown]
# ## Load the CSV data

# %%
import pandas as pd

# %%
ZOO_DATA = '/home/torradeflot/Downloads/ZooSpecPhotoDR19_torradeflot.csv'

# %%
df = pd.read_csv(ZOO_DATA)

# %% [markdown]
# # Filter out incorrect data

# %% [markdown]
# According to the documentation, we will be using the Model magnitude. We filter out the objects without a proper magnitude: https://www.sdss4.org/dr12/algorithms/magnitudes/
#
# We will apply a restrictive threshold in the zooSpec table to decide if an object was successfully classified
#
# We will only keep the objects that are reasonable big, but still fit comfortably in the cutouts.

# %%
m = (
    (df.modelMag_u >-30) & (df.modelMag_g > -30) & (df.modelMag_r > -30) & (df.modelMag_i > -30) & (df.modelMag_z > -30) # correct magnitudes
    & (df.modelMagErr_u < 0.5) & (df.modelMagErr_g < 0.05) & (df.modelMagErr_r < 0.05) & (df.modelMagErr_i < 0.05) & (df.modelMagErr_z < 0.1) # reasonable errors
    & ((df.p_cs_debiased >= 0.9) | (df.p_el_debiased >= 0.9)) # very certain about the classification
    & (df.petroR90_r*2*1.5/0.4 < 64) & (df.petroR90_r*2/0.4 > 20) # Medium sized
)

# %%
len(df), len(df[m])
# Out:
# (659272, 69352)

# %%
cols_to_keep = ['specobjid', 'objid', 'dr7objid', 'ra', 'dec', 'p_el_debiased', 'p_cs_debiased', 'spiral', 'elliptical'] + \
    ['petroR50_r', 'petroR90_r'] + [f'modelMag_{f}' for f in "ugriz"] + [f'extinction_{f}' for f in "ugriz"]
df_filtered = df[m][cols_to_keep]

# %%
df_filtered.to_csv('resources/ZooSpecPhotoDR19_filtered.csv')

# %%
import os
from PIL import Image

image_path = "C:\Users\marce\Desktop\HEP\Sem1 - Statistics\coding_project\final_code\HIPS2FITS_petro\00\0.jpg"
img = Image.open(image_path).convert('L')

img_array = np.array(img)

U,sigma,Vt = np.linalg.svd(img)

k=10

Uk = U[:,:k]
sigmak = np.diag(sigma[:k])
Vtk = Vt[:k,:]

A_dn = Uk @ sigmak @ Vtk

# %%
import pandas
import numpy as np
import os
from PIL import Image

# %%
w = pd.read_csv(r"C:\Users\marce\Desktop\HEP\Sem1 - Statistics\coding_project\final_code\ZooSpecPhotoDR19_filtered.csv",dtype={'dr7objid':str})

# %%
def svd_denoise_features(df, id_col, data_dir, k, grayscale = True):
    if not (0 < k <= 64):
        print(f"{k} needs to be between 0 and 64")

    svd_feature_list = []

    for index, row in df.iterrows():
        print(f'Starting SVD for row {index+1}/{len(df)}\r')
        raw_id = row[id_col]

        img_id_str = str(raw_id)
        subfolder = img_id_str[-2:]
        
        img_name = str(raw_id)+".jpg"
        subfolder_path = os.path.join(data_dir, subfolder)
        img_path = os.path.join(subfolder_path, img_name)

        # now load images
        img = Image.open(img_path)
        if grayscale: # reduce dimensions by converting to grayscale
            A = np.array(img.convert('L'), dtype=np.float64)
        
        # SVD
        sigma = np.linalg.svd(A, compute_uv=False) # U and V are the upper and lower triangular matrices associated with the images, not necessary
        top_k_vals = sigma[:k]
        svd_row = {id_col: raw_id}
        for i in range(k):
            svd_row[f'svd_comp_{i+1}'] = top_k_vals[i]
        svd_feature_list.append(svd_row)

    print("SVD Complete")
    svd_df = pd.DataFrame(svd_feature_list)
    svd_df.to_csv(f'SVD_features_{k}.csv')
    print("SVD features saved as csv")
    return svd_df

# %%
data_dir = r"C:\Users\marce\Desktop\HEP\Sem1 - Statistics\coding_project\final_code\HIPS2FITS_petro"
k = 20
id_col = 'objid'
svd_results = svd_denoise_features(w,id_col=id_col,data_dir=data_dir,k=k)
# Out:
# Starting SVD for row 1/69352
# Starting SVD for row 2/69352
# Starting SVD for row 3/69352
# Starting SVD for row 4/69352
# Starting SVD for row 5/69352
# Starting SVD for row 6/69352
# Starting SVD for row 7/69352
# Starting SVD for row 8/69352
# Starting SVD for row 9/69352
# Starting SVD for row 10/69352
# Starting SVD for row 11/69352
# Starting SVD for row 12/69352
# Starting SVD for row 13/69352
# Starting SVD for row 14/69352
# Starting SVD for row 15/69352
# Starting SVD for row 16/69352
# Starting SVD for row 17/69352
# Starting SVD for row 18/69352
# Starting SVD for row 19/69352
# Starting SVD for row 20/69352
# Starting SVD for row 21/69352
# Starting SVD for row 22/69352
# Starting SVD for row 23/69352
# Starting SVD for row 24/69352
# Starting SVD for row 25/69352
# Starting SVD for row 26/69352
# Starting SVD for row 27/69352
# Starting SVD for row 28/69352
# Starting SVD for row 29/69352
# Starting SVD for row 30/69352
# Starting SVD for row 31/69352
# Starting SVD for row 32/69352
# Starting SVD for row 33/69352
# Starting SVD for row 34/69352
# Starting SVD for row 35/69352
# Starting SVD for row 36/69352
# Starting SVD for row 37/69352
# Starting SVD for row 38/69352
# Starting SVD for row 39/69352
# Starting SVD for row 40/69352
# Starting SVD for row 41/69352
# Starting SVD for row 42/69352
# Starting SVD for row 43/69352
# Starting SVD for row 44/69352
# Starting SVD for row 45/69352
# Starting SVD for row 46/69352
# Starting SVD for row 47/69352
# Starting SVD for row 48/69352
# Starting SVD for row 49/69352
# Starting SVD for row 50/69352
# Starting SVD for row 51/69352
# Starting SVD for row 52/69352
# Starting SVD for row 53/69352
# Starting SVD for row 54/69352
# Starting SVD for row 55/69352
# Starting SVD for row 56/69352
# Starting SVD for row 57/69352
# Starting SVD for row 58/69352
# Starting SVD for row 59/69352
# Starting SVD for row 60/69352
# Starting SVD for row 61/69352
# Starting SVD for row 62/69352
# Starting SVD for row 63/69352
# Starting SVD for row 64/69352
# Starting SVD for row 65/69352
# Starting SVD for row 66/69352
# Starting SVD for row 67/69352
# Starting SVD for row 68/69352
# Starting SVD for row 69/69352
# Starting SVD for row 70/69352
# Starting SVD for row 71/69352
# Starting SVD for row 72/69352
# Starting SVD for row 73/69352
# Starting SVD for row 74/69352
# Starting SVD for row 75/69352
# Starting SVD for row 76/69352
# Starting SVD for row 77/69352
# Starting SVD for row 78/69352
# Starting SVD for row 79/69352
# Starting SVD for row 80/69352
# Starting SVD for row 81/69352
# Starting SVD for row 82/69352
# Starting SVD for row 83/69352
# Starting SVD for row 84/69352
# Starting SVD for row 85/69352
# Starting SVD for row 86/69352
# Starting SVD for row 87/69352
# Starting SVD for row 88/69352
# Starting SVD for row 89/69352
# Starting SVD for row 90/69352
# Starting SVD for row 91/69352
# Starting SVD for row 92/69352
# Starting SVD for row 93/69352
# Starting SVD for row 94/69352
# Starting SVD for row 95/69352
# Starting SVD for row 96/69352
# Starting SVD for row 97/69352
# Starting SVD for row 98/69352
# Starting SVD for row 99/69352
# Starting SVD for row 100/69352
# Starting SVD for row 101/69352
# Starting SVD for row 102/69352
# Starting SVD for row 103/69352
# Starting SVD for row 104/69352
# Starting SVD for row 105/69352
# Starting SVD for row 106/69352
# Starting SVD for row 107/69352
# Starting SVD for row 108/69352
# Starting SVD for row 109/69352
# Starting SVD for row 110/69352
# Starting SVD for row 111/69352
# Starting SVD for row 112/69352
# Starting SVD for row 113/69352
# Starting SVD for row 114/69352
# Starting SVD for row 115/69352
# Starting SVD for row 116/69352
# Starting SVD for row 117/69352
# Starting SVD for row 118/69352
# Starting SVD for row 119/69352
# Starting SVD for row 120/69352
# Starting SVD for row 121/69352
# Starting SVD for row 122/69352
# Starting SVD for row 123/69352
# Starting SVD for row 124/69352
# Starting SVD for row 125/69352
# Starting SVD for row 126/69352
# Starting SVD for row 127/69352
# Starting SVD for row 128/69352
# Starting SVD for row 129/69352
# Starting SVD for row 130/69352
# Starting SVD for row 131/69352
# Starting SVD for row 132/69352
# Starting SVD for row 133/69352
# Starting SVD for row 134/69352
# Starting SVD for row 135/69352
# Starting SVD for row 136/69352
# Starting SVD for row 137/69352
# Starting SVD for row 138/69352
# Starting SVD for row 139/69352
# Starting SVD for row 140/69352
# Starting SVD for row 141/69352
# Starting SVD for row 142/69352
# Starting SVD for row 143/69352
# Starting SVD for row 144/69352
# Starting SVD for row 145/69352
# Starting SVD for row 146/69352
# Starting SVD for row 147/69352
# Starting SVD for row 148/69352
# Starting SVD for row 149/69352
# Starting SVD for row 150/69352
# Starting SVD for row 151/69352
# Starting SVD for row 152/69352
# Starting SVD for row 153/69352
# Starting SVD for row 154/69352
# Starting SVD for row 155/69352
# Starting SVD for row 156/69352
# Starting SVD for row 157/69352
# Starting SVD for row 158/69352
# Starting SVD for row 159/69352
# Starting SVD for row 160/69352
# Starting SVD for row 161/69352
# Starting SVD for row 162/69352
# Starting SVD for row 163/69352
# Starting SVD for row 164/69352
# Starting SVD for row 165/69352
# Starting SVD for row 166/69352
# Starting SVD for row 167/69352
# Starting SVD for row 168/69352
# Starting SVD for row 169/69352
# Starting SVD for row 170/69352
# Starting SVD for row 171/69352
# Starting SVD for row 172/69352
# Starting SVD for row 173/69352
# Starting SVD for row 174/69352
# Starting SVD for row 175/69352
# Starting SVD for row 176/69352
# Starting SVD for row 177/69352
# Starting SVD for row 178/69352
# Starting SVD for row 179/69352
# Starting SVD for row 180/69352
# Starting SVD for row 181/69352
# Starting SVD for row 182/69352
# Starting SVD for row 183/69352
# Starting SVD for row 184/69352
# Starting SVD for row 185/69352
# Starting SVD for row 186/69352
# Starting SVD for row 187/69352
# Starting SVD for row 188/69352
# Starting SVD for row 189/69352
# Starting SVD for row 190/69352
# Starting SVD for row 191/69352
# Starting SVD for row 192/69352
# Starting SVD for row 193/69352
# Starting SVD for row 194/69352
# Starting SVD for row 195/69352
# Starting SVD for row 196/69352
# Starting SVD for row 197/69352
# Starting SVD for row 198/69352
# Starting SVD for row 199/69352
# Starting SVD for row 200/69352
# Starting SVD for row 201/69352
# Starting SVD for row 202/69352
# Starting SVD for row 203/69352
# Starting SVD for row 204/69352
# Starting SVD for row 205/69352
# Starting SVD for row 206/69352
# Starting SVD for row 207/69352
# Starting SVD for row 208/69352
# Starting SVD for row 209/69352
# Starting SVD for row 210/69352
# Starting SVD for row 211/69352
# Starting SVD for row 212/69352
# Starting SVD for row 213/69352
# Starting SVD for row 214/69352
# Starting SVD for row 215/69352
# Starting SVD for row 216/69352
# Starting SVD for row 217/69352
# Starting SVD for row 218/69352
# Starting SVD for row 219/69352
# Starting SVD for row 220/69352
# Starting SVD for row 221/69352
# Starting SVD for row 222/69352
# Starting SVD for row 223/69352
# Starting SVD for row 224/69352
# Starting SVD for row 225/69352
# Starting SVD for row 226/69352
# Starting SVD for row 227/69352
# Starting SVD for row 228/69352
# Starting SVD for row 229/69352
# Starting SVD for row 230/69352
# Starting SVD for row 231/69352
# Starting SVD for row 232/69352
# Starting SVD for row 233/69352
# Starting SVD for row 234/69352
# Starting SVD for row 235/69352
# Starting SVD for row 236/69352
# Starting SVD for row 237/69352
# Starting SVD for row 238/69352
# Starting SVD for row 239/69352
# Starting SVD for row 240/69352
# Starting SVD for row 241/69352
# Starting SVD for row 242/69352
# Starting SVD for row 243/69352
# Starting SVD for row 244/69352
# Starting SVD for row 245/69352
# Starting SVD for row 246/69352
# Starting SVD for row 247/69352
# Starting SVD for row 248/69352
# Starting SVD for row 249/69352
# Starting SVD for row 250/69352
# Starting SVD for row 251/69352
# Starting SVD for row 252/69352
# Starting SVD for row 253/69352
# Starting SVD for row 254/69352
# Starting SVD for row 255/69352
# Starting SVD for row 256/69352
# Starting SVD for row 257/69352
# Starting SVD for row 258/69352
# Starting SVD for row 259/69352
# Starting SVD for row 260/69352
# Starting SVD for row 261/69352
# Starting SVD for row 262/69352
# Starting SVD for row 263/69352
# Starting SVD for row 264/69352
# Starting SVD for row 265/69352
# Starting SVD for row 266/69352
# Starting SVD for row 267/69352
# Starting SVD for row 268/69352
# Starting SVD for row 269/69352
# Starting SVD for row 270/69352
# Starting SVD for row 271/69352
# Starting SVD for row 272/69352
# Starting SVD for row 273/69352
# Starting SVD for row 274/69352
# Starting SVD for row 275/69352
# Starting SVD for row 276/69352
# Starting SVD for row 277/69352
# Starting SVD for row 278/69352
# Starting SVD for row 279/69352
# Starting SVD for row 280/69352
# Starting SVD for row 281/69352
# Starting SVD for row 282/69352
# Starting SVD for row 283/69352
# Starting SVD for row 284/69352
# Starting SVD for row 285/69352
# Starting SVD for row 286/69352
# Starting SVD for row 287/69352
# Starting SVD for row 288/69352
# Starting SVD for row 289/69352
# Starting SVD for row 290/69352
# Starting SVD for row 291/69352
# Starting SVD for row 292/69352
# Starting SVD for row 293/69352
# Starting SVD for row 294/69352
# Starting SVD for row 295/69352
# Starting SVD for row 296/69352
# Starting SVD for row 297/69352
# Starting SVD for row 298/69352
# Starting SVD for row 299/69352
# Starting SVD for row 300/69352
# Starting SVD for row 301/69352
# Starting SVD for row 302/69352
# Starting SVD for row 303/69352
# Starting SVD for row 304/69352
# Starting SVD for row 305/69352
# Starting SVD for row 306/69352
# Starting SVD for row 307/69352
# Starting SVD for row 308/69352
# Starting SVD for row 309/69352
# Starting SVD for row 310/69352
# Starting SVD for row 311/69352
# Starting SVD for row 312/69352
# Starting SVD for row 313/69352
# Starting SVD for row 314/69352
# Starting SVD for row 315/69352
# Starting SVD for row 316/69352
# Starting SVD for row 317/69352
# Starting SVD for row 318/69352
# Starting SVD for row 319/69352
# Starting SVD for row 320/69352
# Starting SVD for row 321/69352
# Starting SVD for row 322/69352
# Starting SVD for row 323/69352
# Starting SVD for row 324/69352
# Starting SVD for row 325/69352
# Starting SVD for row 326/69352
# Starting SVD for row 327/69352
# Starting SVD for row 328/69352
# Starting SVD for row 329/69352
# Starting SVD for row 330/69352
# Starting SVD for row 331/69352
# Starting SVD for row 332/69352
# Starting SVD for row 333/69352
# Starting SVD for row 334/69352
# Starting SVD for row 335/69352
# Starting SVD for row 336/69352
# Starting SVD for row 337/69352
# Starting SVD for row 338/69352
# Starting SVD for row 339/69352
# Starting SVD for row 340/69352
# Starting SVD for row 341/69352
# Starting SVD for row 342/69352
# Starting SVD for row 343/69352
# Starting SVD for row 344/69352
# Starting SVD for row 345/69352
# Starting SVD for row 346/69352
# Starting SVD for row 347/69352
# Starting SVD for row 348/69352
# Starting SVD for row 349/69352
# Starting SVD for row 350/69352
# Starting SVD for row 351/69352
# Starting SVD for row 352/69352
# Starting SVD for row 353/69352
# Starting SVD for row 354/69352
# Starting SVD for row 355/69352
# Starting SVD for row 356/69352
# Starting SVD for row 357/69352
# Starting SVD for row 358/69352
# Starting SVD for row 359/69352
# Starting SVD for row 360/69352
# Starting SVD for row 361/69352
# Starting SVD for row 362/69352
# Starting SVD for row 363/69352
# Starting SVD for row 364/69352
# Starting SVD for row 365/69352
# Starting SVD for row 366/69352
# Starting SVD for row 367/69352
# Starting SVD for row 368/69352
# Starting SVD for row 369/69352
# Starting SVD for row 370/69352
# Starting SVD for row 371/69352
# Starting SVD for row 372/69352
# Starting SVD for row 373/69352
# Starting SVD for row 374/69352
# Starting SVD for row 375/69352
# Starting SVD for row 376/69352
# Starting SVD for row 377/69352
# Starting SVD for row 378/69352
# Starting SVD for row 379/69352
# Starting SVD for row 380/69352
# Starting SVD for row 381/69352
# Starting SVD for row 382/69352
# Starting SVD for row 383/69352
# Starting SVD for row 384/69352
# Starting SVD for row 385/69352
# Starting SVD for row 386/69352
# Starting SVD for row 387/69352
# Starting SVD for row 388/69352
# Starting SVD for row 389/69352
# Starting SVD for row 390/69352
# Starting SVD for row 391/69352
# Starting SVD for row 392/69352
# Starting SVD for row 393/69352
# Starting SVD for row 394/69352
# Starting SVD for row 395/69352
# Starting SVD for row 396/69352
# Starting SVD for row 397/69352
# Starting SVD for row 398/69352
# Starting SVD for row 399/69352
# Starting SVD for row 400/69352
# Starting SVD for row 401/69352
# Starting SVD for row 402/69352
# Starting SVD for row 403/69352
# Starting SVD for row 404/69352
# Starting SVD for row 405/69352
# Starting SVD for row 406/69352
# Starting SVD for row 407/69352
# Starting SVD for row 408/69352
# Starting SVD for row 409/69352
# Starting SVD for row 410/69352
# Starting SVD for row 411/69352
# Starting SVD for row 412/69352
# Starting SVD for row 413/69352
# Starting SVD for row 414/69352
# Starting SVD for row 415/69352
# Starting SVD for row 416/69352
# Starting SVD for row 417/69352
# Starting SVD for row 418/69352
# Starting SVD for row 419/69352
# Starting SVD for row 420/69352
# Starting SVD for row 421/69352
# Starting SVD for row 422/69352
# Starting SVD for row 423/69352
# Starting SVD for row 424/69352
# Starting SVD for row 425/69352
# Starting SVD for row 426/69352
# Starting SVD for row 427/69352
# Starting SVD for row 428/69352
# Starting SVD for row 429/69352
# Starting SVD for row 430/69352
# Starting SVD for row 431/69352
# Starting SVD for row 432/69352
# Starting SVD for row 433/69352
# Starting SVD for row 434/69352
# Starting SVD for row 435/69352
# Starting SVD for row 436/69352
# Starting SVD for row 437/69352
# Starting SVD for row 438/69352
# Starting SVD for row 439/69352
# Starting SVD for row 440/69352
# Starting SVD for row 441/69352
# Starting SVD for row 442/69352
# Starting SVD for row 443/69352
# Starting SVD for row 444/69352
# Starting SVD for row 445/69352
# Starting SVD for row 446/69352
# Starting SVD for row 447/69352
# Starting SVD for row 448/69352
# Starting SVD for row 449/69352
# Starting SVD for row 450/69352
# Starting SVD for row 451/69352
# Starting SVD for row 452/69352
# Starting SVD for row 453/69352
# Starting SVD for row 454/69352
# Starting SVD for row 455/69352
# Starting SVD for row 456/69352
# Starting SVD for row 457/69352
# Starting SVD for row 458/69352
# Starting SVD for row 459/69352
# Starting SVD for row 460/69352
# Starting SVD for row 461/69352
# Starting SVD for row 462/69352
# Starting SVD for row 463/69352
# Starting SVD for row 464/69352
# Starting SVD for row 465/69352
# Starting SVD for row 466/69352
# Starting SVD for row 467/69352
# Starting SVD for row 468/69352
# Starting SVD for row 469/69352
# Starting SVD for row 470/69352
# Starting SVD for row 471/69352
# Starting SVD for row 472/69352
# Starting SVD for row 473/69352
# Starting SVD for row 474/69352
# Starting SVD for row 475/69352
# Starting SVD for row 476/69352
# Starting SVD for row 477/69352
# Starting SVD for row 478/69352
# Starting SVD for row 479/69352
# Starting SVD for row 480/69352
# Starting SVD for row 481/69352
# Starting SVD for row 482/69352
# Starting SVD for row 483/69352
# Starting SVD for row 484/69352
# Starting SVD for row 485/69352
# Starting SVD for row 486/69352
# Starting SVD for row 487/69352
# Starting SVD for row 488/69352
# Starting SVD for row 489/69352
# Starting SVD for row 490/69352
# Starting SVD for row 491/69352
# Starting SVD for row 492/69352
# Starting SVD for row 493/69352
# Starting SVD for row 494/69352
# Starting SVD for row 495/69352
# Starting SVD for row 496/69352
# Starting SVD for row 497/69352
# Starting SVD for row 498/69352
# Starting SVD for row 499/69352
# Starting SVD for row 500/69352
# Starting SVD for row 501/69352
# Starting SVD for row 502/69352
# Starting SVD for row 503/69352
# Starting SVD for row 504/69352
# Starting SVD for row 505/69352
# Starting SVD for row 506/69352
# Starting SVD for row 507/69352
# Starting SVD for row 508/69352
# Starting SVD for row 509/69352
# Starting SVD for row 510/69352
# Starting SVD for row 511/69352
# Starting SVD for row 512/69352
# Starting SVD for row 513/69352
# Starting SVD for row 514/69352
# Starting SVD for row 515/69352
# Starting SVD for row 516/69352
# Starting SVD for row 517/69352
# Starting SVD for row 518/69352
# Starting SVD for row 519/69352
# Starting SVD for row 520/69352
# Starting SVD for row 521/69352
# Starting SVD for row 522/69352
# Starting SVD for row 523/69352
# Starting SVD for row 524/69352
# Starting SVD for row 525/69352
# Starting SVD for row 526/69352
# Starting SVD for row 527/69352
# Starting SVD for row 528/69352
# Starting SVD for row 529/69352
# Starting SVD for row 530/69352
# Starting SVD for row 531/69352
# Starting SVD for row 532/69352
# Starting SVD for row 533/69352
# Starting SVD for row 534/69352
# Starting SVD for row 535/69352
# Starting SVD for row 536/69352
# Starting SVD for row 537/69352
# Starting SVD for row 538/69352
# Starting SVD for row 539/69352
# Starting SVD for row 540/69352
# Starting SVD for row 541/69352
# Starting SVD for row 542/69352
# Starting SVD for row 543/69352
# Starting SVD for row 544/69352
# Starting SVD for row 545/69352
# Starting SVD for row 546/69352
# Starting SVD for row 547/69352
# Starting SVD for row 548/69352
# Starting SVD for row 549/69352
# Starting SVD for row 550/69352
# Starting SVD for row 551/69352
# Starting SVD for row 552/69352
# Starting SVD for row 553/69352
# Starting SVD for row 554/69352
# Starting SVD for row 555/69352
# Starting SVD for row 556/69352
# Starting SVD for row 557/69352
# Starting SVD for row 558/69352
# Starting SVD for row 559/69352
# Starting SVD for row 560/69352
# Starting SVD for row 561/69352
# Starting SVD for row 562/69352
# Starting SVD for row 563/69352
# Starting SVD for row 564/69352
# Starting SVD for row 565/69352
# Starting SVD for row 566/69352
# Starting SVD for row 567/69352
# Starting SVD for row 568/69352
# Starting SVD for row 569/69352
# Starting SVD for row 570/69352
# Starting SVD for row 571/69352
# Starting SVD for row 572/69352
# Starting SVD for row 573/69352
# Starting SVD for row 574/69352
# Starting SVD for row 575/69352
# Starting SVD for row 576/69352
# Starting SVD for row 577/69352
# Starting SVD for row 578/69352
# Starting SVD for row 579/69352
# Starting SVD for row 580/69352
# Starting SVD for row 581/69352
# Starting SVD for row 582/69352
# Starting SVD for row 583/69352
# Starting SVD for row 584/69352
# Starting SVD for row 585/69352
# Starting SVD for row 586/69352
# Starting SVD for row 587/69352
# Starting SVD for row 588/69352
# Starting SVD for row 589/69352
# Starting SVD for row 590/69352
# Starting SVD for row 591/69352
# Starting SVD for row 592/69352
# Starting SVD for row 593/69352
# Starting SVD for row 594/69352
# Starting SVD for row 595/69352
# Starting SVD for row 596/69352
# Starting SVD for row 597/69352
# Starting SVD for row 598/69352
# Starting SVD for row 599/69352
# Starting SVD for row 600/69352
# Starting SVD for row 601/69352
# Starting SVD for row 602/69352
# Starting SVD for row 603/69352
# Starting SVD for row 604/69352
# Starting SVD for row 605/69352
# Starting SVD for row 606/69352
# Starting SVD for row 607/69352
# Starting SVD for row 608/69352
# Starting SVD for row 609/69352
# Starting SVD for row 610/69352
# Starting SVD for row 611/69352
# Starting SVD for row 612/69352
# Starting SVD for row 613/69352
# Starting SVD for row 614/69352
# Starting SVD for row 615/69352
# Starting SVD for row 616/69352
# Starting SVD for row 617/69352
# Starting SVD for row 618/69352
# Starting SVD for row 619/69352
# Starting SVD for row 620/69352
# Starting SVD for row 621/69352
# Starting SVD for row 622/69352
# Starting SVD for row 623/69352
# Starting SVD for row 624/69352
# Starting SVD for row 625/69352
# Starting SVD for row 626/69352
# Starting SVD for row 627/69352
# Starting SVD for row 628/69352
# Starting SVD for row 629/69352
# Starting SVD for row 630/69352
# Starting SVD for row 631/69352
# Starting SVD for row 632/69352
# Starting SVD for row 633/69352
# Starting SVD for row 634/69352
# Starting SVD for row 635/69352
# Starting SVD for row 636/69352
# Starting SVD for row 637/69352
# Starting SVD for row 638/69352
# Starting SVD for row 639/69352
# Starting SVD for row 640/69352
# Starting SVD for row 641/69352
# Starting SVD for row 642/69352
# Starting SVD for row 643/69352
# Starting SVD for row 644/69352
# Starting SVD for row 645/69352
# Starting SVD for row 646/69352
# Starting SVD for row 647/69352
# Starting SVD for row 648/69352
# Starting SVD for row 649/69352
# Starting SVD for row 650/69352
# Starting SVD for row 651/69352
# Starting SVD for row 652/69352
# Starting SVD for row 653/69352
# Starting SVD for row 654/69352
# Starting SVD for row 655/69352
# Starting SVD for row 656/69352
# Starting SVD for row 657/69352
# Starting SVD for row 658/69352
# Starting SVD for row 659/69352
# Starting SVD for row 660/69352
# Starting SVD for row 661/69352
# Starting SVD for row 662/69352
# Starting SVD for row 663/69352
# Starting SVD for row 664/69352
# Starting SVD for row 665/69352
# Starting SVD for row 666/69352
# Starting SVD for row 667/69352
# Starting SVD for row 668/69352
# Starting SVD for row 669/69352
# Starting SVD for row 670/69352
# Starting SVD for row 671/69352
# Starting SVD for row 672/69352
# Starting SVD for row 673/69352
# Starting SVD for row 674/69352
# Starting SVD for row 675/69352
# Starting SVD for row 676/69352
# Starting SVD for row 677/69352
# Starting SVD for row 678/69352
# Starting SVD for row 679/69352
# Starting SVD for row 680/69352
# Starting SVD for row 681/69352
# Starting SVD for row 682/69352
# Starting SVD for row 683/69352
# Starting SVD for row 684/69352
# Starting SVD for row 685/69352
# Starting SVD for row 686/69352
# Starting SVD for row 687/69352
# Starting SVD for row 688/69352
# Starting SVD for row 689/69352
# Starting SVD for row 690/69352
# Starting SVD for row 691/69352
# Starting SVD for row 692/69352
# Starting SVD for row 693/69352
# Starting SVD for row 694/69352
# Starting SVD for row 695/69352
# Starting SVD for row 696/69352
# Starting SVD for row 697/69352
# Starting SVD for row 698/69352
# Starting SVD for row 699/69352
# Starting SVD for row 700/69352
# Starting SVD for row 701/69352
# Starting SVD for row 702/69352
# Starting SVD for row 703/69352
# Starting SVD for row 704/69352
# Starting SVD for row 705/69352
# Starting SVD for row 706/69352
# Starting SVD for row 707/69352
# Starting SVD for row 708/69352
# Starting SVD for row 709/69352
# Starting SVD for row 710/69352
# Starting SVD for row 711/69352
# Starting SVD for row 712/69352
# Starting SVD for row 713/69352
# Starting SVD for row 714/69352
# Starting SVD for row 715/69352
# Starting SVD for row 716/69352
# Starting SVD for row 717/69352
# Starting SVD for row 718/69352
# Starting SVD for row 719/69352
# Starting SVD for row 720/69352
# Starting SVD for row 721/69352
# Starting SVD for row 722/69352
# Starting SVD for row 723/69352
# Starting SVD for row 724/69352
# Starting SVD for row 725/69352
# Starting SVD for row 726/69352
# Starting SVD for row 727/69352
# Starting SVD for row 728/69352
# Starting SVD for row 729/69352
# Starting SVD for row 730/69352
# Starting SVD for row 731/69352
# Starting SVD for row 732/69352
# Starting SVD for row 733/69352
# Starting SVD for row 734/69352
# Starting SVD for row 735/69352
# Starting SVD for row 736/69352
# Starting SVD for row 737/69352
# Starting SVD for row 738/69352
# Starting SVD for row 739/69352
# Starting SVD for row 740/69352
# Starting SVD for row 741/69352
# Starting SVD for row 742/69352
# Starting SVD for row 743/69352
# Starting SVD for row 744/69352
# Starting SVD for row 745/69352
# Starting SVD for row 746/69352
# Starting SVD for row 747/69352
# Starting SVD for row 748/69352
# Starting SVD for row 749/69352
# Starting SVD for row 750/69352
# Starting SVD for row 751/69352
# Starting SVD for row 752/69352
# Starting SVD for row 753/69352
# Starting SVD for row 754/69352
# Starting SVD for row 755/69352
# Starting SVD for row 756/69352
# Starting SVD for row 757/69352
# Starting SVD for row 758/69352
# Starting SVD for row 759/69352
# Starting SVD for row 760/69352
# Starting SVD for row 761/69352
# Starting SVD for row 762/69352
# Starting SVD for row 763/69352
# Starting SVD for row 764/69352
# Starting SVD for row 765/69352
# Starting SVD for row 766/69352
# Starting SVD for row 767/69352
# Starting SVD for row 768/69352
# Starting SVD for row 769/69352
# Starting SVD for row 770/69352
# Starting SVD for row 771/69352
# Starting SVD for row 772/69352
# Starting SVD for row 773/69352
# Starting SVD for row 774/69352
# Starting SVD for row 775/69352
# Starting SVD for row 776/69352
# Starting SVD for row 777/69352
# Starting SVD for row 778/69352
# Starting SVD for row 779/69352
# Starting SVD for row 780/69352
# Starting SVD for row 781/69352
# Starting SVD for row 782/69352
# Starting SVD for row 783/69352
# Starting SVD for row 784/69352
# Starting SVD for row 785/69352
# Starting SVD for row 786/69352
# Starting SVD for row 787/69352
# Starting SVD for row 788/69352
# Starting SVD for row 789/69352
# Starting SVD for row 790/69352
# Starting SVD for row 791/69352
# Starting SVD for row 792/69352
# Starting SVD for row 793/69352
# Starting SVD for row 794/69352
# Starting SVD for row 795/69352
# Starting SVD for row 796/69352
# Starting SVD for row 797/69352
# Starting SVD for row 798/69352
# Starting SVD for row 799/69352
# Starting SVD for row 800/69352
# Starting SVD for row 801/69352
# Starting SVD for row 802/69352
# Starting SVD for row 803/69352
# Starting SVD for row 804/69352
# Starting SVD for row 805/69352
# Starting SVD for row 806/69352
# Starting SVD for row 807/69352
# Starting SVD for row 808/69352
# Starting SVD for row 809/69352
# Starting SVD for row 810/69352
# Starting SVD for row 811/69352
# Starting SVD for row 812/69352
# Starting SVD for row 813/69352
# Starting SVD for row 814/69352
# Starting SVD for row 815/69352
# Starting SVD for row 816/69352
# Starting SVD for row 817/69352
# Starting SVD for row 818/69352
# Starting SVD for row 819/69352
# Starting SVD for row 820/69352
# Starting SVD for row 821/69352
# Starting SVD for row 822/69352
# Starting SVD for row 823/69352
# Starting SVD for row 824/69352
# Starting SVD for row 825/69352
# Starting SVD for row 826/69352
# Starting SVD for row 827/69352
# Starting SVD for row 828/69352
# Starting SVD for row 829/69352
# Starting SVD for row 830/69352
# Starting SVD for row 831/69352
# Starting SVD for row 832/69352
# Starting SVD for row 833/69352
# Starting SVD for row 834/69352
# Starting SVD for row 835/69352
# Starting SVD for row 836/69352
# Starting SVD for row 837/69352
# Starting SVD for row 838/69352
# Starting SVD for row 839/69352
# Starting SVD for row 840/69352
# Starting SVD for row 841/69352
# Starting SVD for row 842/69352
# Starting SVD for row 843/69352
# Starting SVD for row 844/69352
# Starting SVD for row 845/69352
# Starting SVD for row 846/69352
# Starting SVD for row 847/69352
# Starting SVD for row 848/69352
# Starting SVD for row 849/69352
# Starting SVD for row 850/69352
# Starting SVD for row 851/69352
# Starting SVD for row 852/69352
# Starting SVD for row 853/69352
# Starting SVD for row 854/69352
# Starting SVD for row 855/69352
# Starting SVD for row 856/69352
# Starting SVD for row 857/69352
# Starting SVD for row 858/69352
# Starting SVD for row 859/69352
# Starting SVD for row 860/69352
# Starting SVD for row 861/69352
# Starting SVD for row 862/69352
# Starting SVD for row 863/69352
# Starting SVD for row 864/69352
# Starting SVD for row 865/69352
# Starting SVD for row 866/69352
# Starting SVD for row 867/69352
# Starting SVD for row 868/69352
# Starting SVD for row 869/69352
# Starting SVD for row 870/69352
# Starting SVD for row 871/69352
# Starting SVD for row 872/69352
# Starting SVD for row 873/69352
# Starting SVD for row 874/69352
# Starting SVD for row 875/69352
# Starting SVD for row 876/69352
# Starting SVD for row 877/69352
# Starting SVD for row 878/69352
# Starting SVD for row 879/69352
# Starting SVD for row 880/69352
# Starting SVD for row 881/69352
# Starting SVD for row 882/69352
# Starting SVD for row 883/69352
# Starting SVD for row 884/69352
# Starting SVD for row 885/69352
# Starting SVD for row 886/69352
# Starting SVD for row 887/69352
# Starting SVD for row 888/69352
# Starting SVD for row 889/69352
# Starting SVD for row 890/69352
# Starting SVD for row 891/69352
# Starting SVD for row 892/69352
# Starting SVD for row 893/69352
# Starting SVD for row 894/69352
# Starting SVD for row 895/69352
# Starting SVD for row 896/69352
# Starting SVD for row 897/69352
# Starting SVD for row 898/69352
# Starting SVD for row 899/69352
# Starting SVD for row 900/69352
# Starting SVD for row 901/69352
# Starting SVD for row 902/69352
# Starting SVD for row 903/69352
# Starting SVD for row 904/69352
# Starting SVD for row 905/69352
# Starting SVD for row 906/69352
# Starting SVD for row 907/69352
# Starting SVD for row 908/69352
# Starting SVD for row 909/69352
# Starting SVD for row 910/69352
# Starting SVD for row 911/69352
# Starting SVD for row 912/69352
# Starting SVD for row 913/69352
# Starting SVD for row 914/69352
# Starting SVD for row 915/69352
# Starting SVD for row 916/69352
# Starting SVD for row 917/69352
# Starting SVD for row 918/69352
# Starting SVD for row 919/69352
# Starting SVD for row 920/69352
# Starting SVD for row 921/69352
# Starting SVD for row 922/69352
# Starting SVD for row 923/69352
# Starting SVD for row 924/69352
# Starting SVD for row 925/69352
# Starting SVD for row 926/69352
# Starting SVD for row 927/69352
# Starting SVD for row 928/69352
# Starting SVD for row 929/69352
# Starting SVD for row 930/69352
# Starting SVD for row 931/69352
# Starting SVD for row 932/69352
# Starting SVD for row 933/69352
# Starting SVD for row 934/69352
# Starting SVD for row 935/69352
# Starting SVD for row 936/69352
# Starting SVD for row 937/69352
# Starting SVD for row 938/69352
# Starting SVD for row 939/69352
# Starting SVD for row 940/69352
# Starting SVD for row 941/69352
# Starting SVD for row 942/69352
# Starting SVD for row 943/69352
# Starting SVD for row 944/69352
# Starting SVD for row 945/69352
# Starting SVD for row 946/69352
# Starting SVD for row 947/69352
# Starting SVD for row 948/69352
# Starting SVD for row 949/69352
# Starting SVD for row 950/69352
# Starting SVD for row 951/69352
# Starting SVD for row 952/69352
# Starting SVD for row 953/69352
# Starting SVD for row 954/69352
# Starting SVD for row 955/69352
# Starting SVD for row 956/69352
# Starting SVD for row 957/69352
# Starting SVD for row 958/69352
# Starting SVD for row 959/69352
# Starting SVD for row 960/69352
# Starting SVD for row 961/69352
# Starting SVD for row 962/69352
# Starting SVD for row 963/69352
# Starting SVD for row 964/69352
# Starting SVD for row 965/69352
# Starting SVD for row 966/69352
# Starting SVD for row 967/69352
# Starting SVD for row 968/69352
# Starting SVD for row 969/69352
# Starting SVD for row 970/69352
# Starting SVD for row 971/69352
# Starting SVD for row 972/69352
# Starting SVD for row 973/69352
# Starting SVD for row 974/69352
# Starting SVD for row 975/69352
# Starting SVD for row 976/69352
# Starting SVD for row 977/69352
# Starting SVD for row 978/69352
# Starting SVD for row 979/69352
# Starting SVD for row 980/69352
# Starting SVD for row 981/69352
# Starting SVD for row 982/69352
# Starting SVD for row 983/69352
# Starting SVD for row 984/69352
# Starting SVD for row 985/69352
# Starting SVD for row 986/69352
# Starting SVD for row 987/69352
# Starting SVD for row 988/69352
# Starting SVD for row 989/69352
# Starting SVD for row 990/69352
# Starting SVD for row 991/69352
# Starting SVD for row 992/69352
# Starting SVD for row 993/69352
# Starting SVD for row 994/69352
# Starting SVD for row 995/69352
# Starting SVD for row 996/69352
# Starting SVD for row 997/69352
# Starting SVD for row 998/69352
# Starting SVD for row 999/69352
# Starting SVD for row 1000/69352
# Starting SVD for row 1001/69352
# Starting SVD for row 1002/69352
# Starting SVD for row 1003/69352
# Starting SVD for row 1004/69352
# Starting SVD for row 1005/69352
# Starting SVD for row 1006/69352
# Starting SVD for row 1007/69352
# Starting SVD for row 1008/69352
# Starting SVD for row 1009/69352
# Starting SVD for row 1010/69352
# Starting SVD for row 1011/69352
# Starting SVD for row 1012/69352
# Starting SVD for row 1013/69352
# Starting SVD for row 1014/69352
# Starting SVD for row 1015/69352
# Starting SVD for row 1016/69352
# Starting SVD for row 1017/69352
# Starting SVD for row 1018/69352
# Starting SVD for row 1019/69352
# Starting SVD for row 1020/69352
# Starting SVD for row 1021/69352
# Starting SVD for row 1022/69352
# Starting SVD for row 1023/69352
# Starting SVD for row 1024/69352
# Starting SVD for row 1025/69352
# Starting SVD for row 1026/69352
# Starting SVD for row 1027/69352
# Starting SVD for row 1028/69352
# Starting SVD for row 1029/69352
# Starting SVD for row 1030/69352
# Starting SVD for row 1031/69352
# Starting SVD for row 1032/69352
# Starting SVD for row 1033/69352
# Starting SVD for row 1034/69352
# Starting SVD for row 1035/69352
# Starting SVD for row 1036/69352
# Starting SVD for row 1037/69352
# Starting SVD for row 1038/69352
# Starting SVD for row 1039/69352
# Starting SVD for row 1040/69352
# Starting SVD for row 1041/69352
# Starting SVD for row 1042/69352
# Starting SVD for row 1043/69352
# Starting SVD for row 1044/69352
# Starting SVD for row 1045/69352
# Starting SVD for row 1046/69352
# Starting SVD for row 1047/69352
# Starting SVD for row 1048/69352
# Starting SVD for row 1049/69352
# Starting SVD for row 1050/69352
# Starting SVD for row 1051/69352
# Starting SVD for row 1052/69352
# Starting SVD for row 1053/69352
# Starting SVD for row 1054/69352
# Starting SVD for row 1055/69352
# Starting SVD for row 1056/69352
# Starting SVD for row 1057/69352
# Starting SVD for row 1058/69352
# Starting SVD for row 1059/69352
# Starting SVD for row 1060/69352
# Starting SVD for row 1061/69352
# Starting SVD for row 1062/69352
# Starting SVD for row 1063/69352
# Starting SVD for row 1064/69352
# Starting SVD for row 1065/69352
# Starting SVD for row 1066/69352
# Starting SVD for row 1067/69352
# Starting SVD for row 1068/69352
# Starting SVD for row 1069/69352
# Starting SVD for row 1070/69352
# Starting SVD for row 1071/69352
# Starting SVD for row 1072/69352
# Starting SVD for row 1073/69352
# Starting SVD for row 1074/69352
# Starting SVD for row 1075/69352
# Starting SVD for row 1076/69352
# Starting SVD for row 1077/69352
# Starting SVD for row 1078/69352
# Starting SVD for row 1079/69352
# Starting SVD for row 1080/69352
# Starting SVD for row 1081/69352
# Starting SVD for row 1082/69352
# Starting SVD for row 1083/69352
# Starting SVD for row 1084/69352
# Starting SVD for row 1085/69352
# Starting SVD for row 1086/69352
# Starting SVD for row 1087/69352
# Starting SVD for row 1088/69352
# Starting SVD for row 1089/69352
# Starting SVD for row 1090/69352
# Starting SVD for row 1091/69352
# Starting SVD for row 1092/69352
# Starting SVD for row 1093/69352
# Starting SVD for row 1094/69352
# Starting SVD for row 1095/69352
# Starting SVD for row 1096/69352
# Starting SVD for row 1097/69352
# Starting SVD for row 1098/69352
# Starting SVD for row 1099/69352
# Starting SVD for row 1100/69352
# Starting SVD for row 1101/69352
# Starting SVD for row 1102/69352
# Starting SVD for row 1103/69352
# Starting SVD for row 1104/69352
# Starting SVD for row 1105/69352
# Starting SVD for row 1106/69352
# Starting SVD for row 1107/69352
# Starting SVD for row 1108/69352
# Starting SVD for row 1109/69352
# Starting SVD for row 1110/69352
# Starting SVD for row 1111/69352
# Starting SVD for row 1112/69352
# Starting SVD for row 1113/69352
# Starting SVD for row 1114/69352
# Starting SVD for row 1115/69352
# Starting SVD for row 1116/69352
# Starting SVD for row 1117/69352
# Starting SVD for row 1118/69352
# Starting SVD for row 1119/69352
# Starting SVD for row 1120/69352
# Starting SVD for row 1121/69352
# Starting SVD for row 1122/69352
# Starting SVD for row 1123/69352
# Starting SVD for row 1124/69352
# Starting SVD for row 1125/69352
# Starting SVD for row 1126/69352
# Starting SVD for row 1127/69352
# Starting SVD for row 1128/69352
# Starting SVD for row 1129/69352
# Starting SVD for row 1130/69352
# Starting SVD for row 1131/69352
# Starting SVD for row 1132/69352
# Starting SVD for row 1133/69352
# Starting SVD for row 1134/69352
# Starting SVD for row 1135/69352
# Starting SVD for row 1136/69352
# Starting SVD for row 1137/69352
# Starting SVD for row 1138/69352
# Starting SVD for row 1139/69352
# Starting SVD for row 1140/69352
# Starting SVD for row 1141/69352
# Starting SVD for row 1142/69352
# Starting SVD for row 1143/69352
# Starting SVD for row 1144/69352
# Starting SVD for row 1145/69352
# Starting SVD for row 1146/69352
# Starting SVD for row 1147/69352
# Starting SVD for row 1148/69352
# Starting SVD for row 1149/69352
# Starting SVD for row 1150/69352
# Starting SVD for row 1151/69352
# Starting SVD for row 1152/69352
# Starting SVD for row 1153/69352
# Starting SVD for row 1154/69352
# Starting SVD for row 1155/69352
# Starting SVD for row 1156/69352
# Starting SVD for row 1157/69352
# Starting SVD for row 1158/69352
# Starting SVD for row 1159/69352
# Starting SVD for row 1160/69352
# Starting SVD for row 1161/69352
# Starting SVD for row 1162/69352
# Starting SVD for row 1163/69352
# Starting SVD for row 1164/69352
# Starting SVD for row 1165/69352
# Starting SVD for row 1166/69352
# Starting SVD for row 1167/69352
# Starting SVD for row 1168/69352
# Starting SVD for row 1169/69352
# Starting SVD for row 1170/69352
# Starting SVD for row 1171/69352
# Starting SVD for row 1172/69352
# Starting SVD for row 1173/69352
# Starting SVD for row 1174/69352
# Starting SVD for row 1175/69352
# Starting SVD for row 1176/69352
# Starting SVD for row 1177/69352
# Starting SVD for row 1178/69352
# Starting SVD for row 1179/69352
# Starting SVD for row 1180/69352
# Starting SVD for row 1181/69352
# Starting SVD for row 1182/69352
# Starting SVD for row 1183/69352
# Starting SVD for row 1184/69352
# Starting SVD for row 1185/69352
# Starting SVD for row 1186/69352
# Starting SVD for row 1187/69352
# Starting SVD for row 1188/69352
# Starting SVD for row 1189/69352
# Starting SVD for row 1190/69352
# Starting SVD for row 1191/69352
# Starting SVD for row 1192/69352
# Starting SVD for row 1193/69352
# Starting SVD for row 1194/69352
# Starting SVD for row 1195/69352
# Starting SVD for row 1196/69352
# Starting SVD for row 1197/69352
# Starting SVD for row 1198/69352
# Starting SVD for row 1199/69352
# Starting SVD for row 1200/69352
# Starting SVD for row 1201/69352
# Starting SVD for row 1202/69352
# Starting SVD for row 1203/69352
# Starting SVD for row 1204/69352
# Starting SVD for row 1205/69352
# Starting SVD for row 1206/69352
# Starting SVD for row 1207/69352
# Starting SVD for row 1208/69352
# Starting SVD for row 1209/69352
# Starting SVD for row 1210/69352
# Starting SVD for row 1211/69352
# Starting SVD for row 1212/69352
# Starting SVD for row 1213/69352
# Starting SVD for row 1214/69352
# Starting SVD for row 1215/69352
# Starting SVD for row 1216/69352
# Starting SVD for row 1217/69352
# Starting SVD for row 1218/69352
# Starting SVD for row 1219/69352
# Starting SVD for row 1220/69352
# Starting SVD for row 1221/69352
# Starting SVD for row 1222/69352
# Starting SVD for row 1223/69352
# Starting SVD for row 1224/69352
# Starting SVD for row 1225/69352
# Starting SVD for row 1226/69352
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[63], line 4
#       2 k = 20
#       3 id_col = 'objid'
# ----> 4 svd_results = svd_denoise_features(w,id_col=id_col,data_dir=data_dir,k=k)
#
# Cell In[61], line 19, in svd_denoise_features(df, id_col, data_dir, k, grayscale)
#      16 img_path = os.path.join(subfolder_path, img_name)
#      18 # now load images
# ---> 19 img = Image.open(img_path)
#      20 if grayscale: # reduce dimensions by converting to grayscale
#      21     A = np.array(img.convert('L'), dtype=np.float64)
#
# File ~\anaconda3\envs\pythonbootcamp\Lib\site-packages\PIL\Image.py:3513, in open(fp, mode, formats)
#    3511 if is_path(fp):
#    3512     filename = os.fspath(fp)
# -> 3513     fp = builtins.open(filename, "rb")
#    3514     exclusive_fp = True
#    3515 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\marce\\Desktop\\HEP\\Sem1 - Statistics\\coding_project\\final_code\\HIPS2FITS_petro\\0\\0.jpg'

# %%
import pandas as pd
import numpy as np
import os
from PIL import Image

w = pd.read_excel(r"C:\Users\marce\Desktop\HEP\Sem1 - Statistics\coding_project\final_code\ZooSpecPhotoDR19_filtered.xlsx",dtype={'objid':str})


from sklearn.model_selection import train_test_split



w = w.drop(columns=['spiral','elliptical'])



def svd_denoise_features(df, id_col, data_dir, k, grayscale = True):
    if not (0 < k <= 64):
        print(f"{k} needs to be between 0 and 64")

    svd_feature_list = []
    missing_files = []

    for index, row in df.iterrows():
        print(f'Starting SVD for row {index+1}/{len(df)}',end='\r')
        raw_id = row[id_col]

        img_id_str = str(int(raw_id)).zfill(2)
        subfolder = img_id_str[-2:]
        
        img_name = str(img_id_str)+".jpg"
        subfolder_path = os.path.join(data_dir, subfolder)
        img_path = os.path.join(subfolder_path, img_name)

        # if no image associated with objid, save the id and skip
        if not os.path.exists(img_path):
            missing_files.append(img_path)
            continue

        try:
            # now load images
            img = Image.open(img_path)
            if grayscale: # reduce dimensions by converting to grayscale
                A = np.array(img.convert('L'), dtype=np.float64)
            
            # SVD
            sigma = np.linalg.svd(A, compute_uv=False) # U and V are the upper and lower triangular matrices associated with the images, not necessary
            top_k_vals = sigma[:k]
            svd_row = {id_col: raw_id}
            for i in range(k):
                svd_row[f'svd_comp_{i+1}'] = top_k_vals[i]
            svd_feature_list.append(svd_row)
        except Exception as e:
            print(f"\nError processing {img_path}: {e}")
            missing_files.append(img_path)
            continue

    print("SVD Complete")
    svd_df = pd.DataFrame(svd_feature_list)
    svd_df.to_csv(f'SVD_features_{k}.csv')
    print("SVD features saved as csv")
    return svd_df


data_dir = r"C:\Users\marce\Desktop\HEP\Sem1 - Statistics\coding_project\final_code\HIPS2FITS_petro"
k = 20
id_col = 'objid'
svd_results = svd_denoise_features(w,id_col=id_col,data_dir=data_dir,k=k)
# Out:
# SVD Complete for row 69352/69352
# SVD features saved as csv

# %%
import numpy as np
import pandas as pd

# %%
label_map = {'uncertain':0,
             'spiral':1,
             'elliptical':2}

# %%
svd_results = pd.read_csv(r"C:\Users\marce\Desktop\HEP\Sem1 - Statistics\coding_project\final_code\SVD_features_20.csv")
w = pd.read_excel(r"C:\Users\marce\Desktop\HEP\Sem1 - Statistics\coding_project\final_code\ZooSpecPhotoDR19_filtered.xlsx")

# %%
w_with_svd = w.merge(svd_results,how='inner',on='objid')
w_with_svd['target'] = w_with_svd['target'].map(label_map)
w_with_svd['target'] = w_with_svd['target'].astype(int)

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
train_split = 0.6
val_split = 0.2
test_split = 0.2

X = w_with_svd.copy()
X = X.drop(columns=['objid','dr7objid','specobjid','ra','dec','spiral','elliptical'])

train, temp = train_test_split(X, test_size=(1-train_split), stratify=X['target'],random_state=111)

rel_val_size = val_split / (val_split + test_split)
val, test = train_test_split(temp, test_size=(1-rel_val_size), stratify=temp['target'],random_state =111)

train = train.reset_index(drop=True)
val = val.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
X_train = train.drop(columns=['target'])
y_train = train['target']

X_val = val.drop(columns=['target'])
y_val = val['target']

X_test = test.drop(columns=['target'])
y_test = test['target']

y_train = y_train.astype(int)
y_val = y_val.astype(int)
y_test = y_test.astype(int)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
rf = RandomForestClassifier(random_state=111)
svm = SVC(kernel='rbf', random_state=111)
logreg = LogisticRegression(max_iter=500, multi_class='multinomial', random_state=111)

# Hyperparameter grids
param_grids = {
    'Random Forest': {'n_estimators': [100, 200], 'max_depth': [None, 10, 20]},
    'SVM': {'C': [0.1, 1, 10], 'gamma': ['scale', 'auto']},
    'Logistic Regression': {'C': [0.1, 1, 10]}
}

# %%
from sklearn.metrics import accuracy_score

best_models = {}

# Random Forest
best_acc = 0
for n in [100, 150, 200, 250]:
    for d in [1, 10, 15]:
        rf_tmp = RandomForestClassifier(n_estimators=n, max_depth=d, random_state=111)
        rf_tmp.fit(X_train, y_train)
        y_val_pred = rf_tmp.predict(X_val)
        acc = accuracy_score(y_val, y_val_pred)
        if acc > best_acc:
            best_acc = acc
            best_models['Random Forest'] = rf_tmp
print(f"Best RF val acc: {best_acc:.3f}")

# SVM
best_acc = 0
for C in [0.1, 1, 3, 5, 7, 10]:
    for gamma in ['scale', 'auto']:
        svm_tmp = SVC(C=C, gamma=gamma, kernel='rbf', random_state=111)
        svm_tmp.fit(X_train_scaled, y_train)
        y_val_pred = svm_tmp.predict(X_val_scaled)
        acc = accuracy_score(y_val, y_val_pred)
        if acc > best_acc:
            best_acc = acc
            best_models['SVM'] = svm_tmp
print(f"Best SVM val acc: {best_acc:.3f}")

# Logistic Regression
best_acc = 0
for C in [0.1, 1, 3, 5, 7, 10]:
    logreg_tmp = LogisticRegression(C=C, max_iter=500, multi_class='multinomial', random_state=111)
    logreg_tmp.fit(X_train_scaled, y_train)
    y_val_pred = logreg_tmp.predict(X_val_scaled)
    acc = accuracy_score(y_val, y_val_pred)
    if acc > best_acc:
        best_acc = acc
        best_models['Logistic Regression'] = logreg_tmp
print(f"Best Logistic Regression val acc: {best_acc:.3f}")
# Out:
# Best RF val acc: 0.963
# Best SVM val acc: 0.960
# C:\Users\marce\anaconda3\envs\pythonbootcamp\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\marce\anaconda3\envs\pythonbootcamp\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\marce\anaconda3\envs\pythonbootcamp\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\marce\anaconda3\envs\pythonbootcamp\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\marce\anaconda3\envs\pythonbootcamp\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\marce\anaconda3\envs\pythonbootcamp\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Best Logistic Regression val acc: 0.962

# %%
from sklearn.metrics import classification_report

for name, model in best_models.items():
    if name in ['SVM', 'Logistic Regression']:
        X_used = X_test_scaled
    else:
        X_used = X_test

    y_pred = model.predict(X_used)
    print(f"\n=== {name} Test Results ===")
    print(classification_report(y_test, y_pred))
# Out:
# === Random Forest Test Results ===
#               precision    recall  f1-score   support
#
#            0       0.73      0.24      0.37       619
#            1       0.98      1.00      0.99     10812
#            2       0.90      0.98      0.94      2562
#
#     accuracy                           0.96     13993
#    macro avg       0.87      0.74      0.77     13993
# weighted avg       0.96      0.96      0.95     13993
#
#
# === SVM Test Results ===
#               precision    recall  f1-score   support
#
#            0       0.73      0.19      0.31       619
#            1       0.98      1.00      0.99     10812
#            2       0.90      0.98      0.94      2562
#
#     accuracy                           0.96     13993
#    macro avg       0.87      0.73      0.74     13993
# weighted avg       0.95      0.96      0.95     13993
#
#
# === Logistic Regression Test Results ===
#               precision    recall  f1-score   support
#
#            0       0.64      0.36      0.46       619
#            1       0.98      1.00      0.99     10812
#            2       0.92      0.97      0.94      2562
#
#     accuracy                           0.96     13993
#    macro avg       0.85      0.77      0.80     13993
# weighted avg       0.96      0.96      0.96     13993

# %%
# 1. Check for duplicates between train and test


# 2. Correlation of features with target
corrs = X.corrwith(X['target'])
print(corrs.sort_values(ascending=False).head(10))
# Out:
# target           1.000000
# p_el_debiased    0.681637
# svd_comp_1       0.203409
# modelMag_u       0.166361
# svd_comp_20      0.099418
# svd_comp_19      0.096935
# svd_comp_18      0.095228
# svd_comp_17      0.093834
# svd_comp_16      0.091567
# svd_comp_15      0.087852
# dtype: float64

# %%
train.columns
# Out:
# Index(['Unnamed: 0_x', 'p_el_debiased', 'p_cs_debiased', 'petroR50_r',
#        'petroR90_r', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i',
#        'modelMag_z', 'extinction_u', 'extinction_g', 'extinction_r',
#        'extinction_i', 'extinction_z', 'target', 'Unnamed: 0_y', 'svd_comp_1',
#        'svd_comp_2', 'svd_comp_3', 'svd_comp_4', 'svd_comp_5', 'svd_comp_6',
#        'svd_comp_7', 'svd_comp_8', 'svd_comp_9', 'svd_comp_10', 'svd_comp_11',
#        'svd_comp_12', 'svd_comp_13', 'svd_comp_14', 'svd_comp_15',
#        'svd_comp_16', 'svd_comp_17', 'svd_comp_18', 'svd_comp_19',
#        'svd_comp_20'],
#       dtype='object')

# %%
from sklearn.metrics import classification_report, confusion_matrix, balanced_accuracy_score

print(classification_report(y_test, y_pred))
print("Balanced Accuracy:", balanced_accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.36      0.46       619
#            1       0.98      1.00      0.99     10812
#            2       0.92      0.97      0.94      2562
#
#     accuracy                           0.96     13993
#    macro avg       0.85      0.77      0.80     13993
# weighted avg       0.96      0.96      0.96     13993
#
# Balanced Accuracy: 0.7746019570028335
# [[  224   175   220]
#  [   36 10776     0]
#  [   89     0  2473]]
